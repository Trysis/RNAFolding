# %%
# Data gestion
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
# Pattern matching
import re

# %%
# Constantes
RNA_BASES = [["A"], ["U"], ["C"], ["G"]]
encoder = OneHotEncoder(handle_unknown='ignore').fit(RNA_BASES)

# %%
# Path to csv containing RNA sequence and reactivities
datapath = "./data/SN_filtered_data.csv"

# %%
rna_data = pd.read_csv(datapath, header=0, index_col=0)

# %%
# Visualize first rows in dataset
rna_data.head()
# Out:
#     sequence_id                                           sequence  \
# 1  51e61fbde94d  GGGAACGACUCGAGUAGAGUCGAAAAACAUUGAUAUGGAUUUACUC...
# 2  25ce8d5109cd  GGGAACGACUCGAGUAGAGUCGAAAAACCUUGAUAUGGAUUUACUC...
# 3  07dcfb6d1965  GGGAACGACUCGAGUAGAGUCGAAAAACUUUGAUAUGGAUUUACUC...
# 4  e561cc042a4c  GGGAACGACUCGAGUAGAGUCGAAAAACGAUGAUAUGGAUUUACUC...
# 5  aa948762535f  GGGAACGACUCGAGUAGAGUCGAAAAACGCUGAUAUGGAUUUACUC...
#
#   experiment_type dataset_name     reads  signal_to_noise  SN_filter  \
# 1         2A3_MaP      15k_2A3    5326.0            1.933          1
# 2         2A3_MaP      15k_2A3    4647.0            2.347          1
# 3         2A3_MaP      15k_2A3  102843.0           11.824          1
# 4         2A3_MaP      15k_2A3    7665.0            3.519          1
# 5         2A3_MaP      15k_2A3   14018.0            3.219          1
#
#    reactivity_0001  reactivity_0002  reactivity_0003  ...  \
# 1              NaN              NaN              NaN  ...
# 2              NaN              NaN              NaN  ...
# 3              NaN              NaN              NaN  ...
# 4              NaN              NaN              NaN  ...
# 5              NaN              NaN              NaN  ...
#
#    reactivity_error_0197  reactivity_error_0198  reactivity_error_0199  \
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
# 5                    NaN                    NaN                    NaN
#
#    reactivity_error_0200  reactivity_error_0201  reactivity_error_0202  \
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
# 5                    NaN                    NaN                    NaN
#
#    reactivity_error_0203  reactivity_error_0204  reactivity_error_0205  \
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
# 5                    NaN                    NaN                    NaN
#
#    reactivity_error_0206
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
#
# [5 rows x 419 columns]

# %%
def datatoOneHot(X, col="sequence"):
    """X: pandas.Dataframe"""
    onehot_list = []
    for i, sequence in enumerate(X[col]):
        procc_sequence = [nbase for nbase in sequence]
        print(procc_sequence)
        onehot_list.append(encoder.transform(procc_sequence))
    
    return np.array(onehot_list)

# %%
def datatoXY(dataframe, x_columns, y_columns):
    non_procc_X = dataframe[x_columns]
    non_procc_Y = dataframe[y_columns]
    #
    X = datatoOneHot(non_procc_X)
    
    return X, Y

# %%
# Get columns name for X, and Y
X_cols = ["sequence"]
Y_cols = [colname for colname in rna_data.columns if re.match("^reactivity_[0-9]{4}$", colname)]

datatoXY(dataframe=rna_data[:3],
         x_columns=X_cols,
         y_columns=Y_cols)
# Out:
# ['G', 'G', 'G', 'A', 'A', 'C', 'G', 'A', 'C', 'U', 'C', 'G', 'A', 'G', 'U', 'A', 'G', 'A', 'G', 'U', 'C', 'G', 'A', 'A', 'A', 'A', 'A', 'C', 'A', 'U', 'U', 'G', 'A', 'U', 'A', 'U', 'G', 'G', 'A', 'U', 'U', 'U', 'A', 'C', 'U', 'C', 'C', 'G', 'A', 'G', 'G', 'A', 'G', 'A', 'C', 'G', 'A', 'A', 'C', 'U', 'A', 'C', 'C', 'A', 'C', 'G', 'A', 'A', 'C', 'A', 'G', 'G', 'G', 'G', 'A', 'A', 'A', 'C', 'U', 'C', 'U', 'A', 'C', 'C', 'C', 'G', 'U', 'G', 'G', 'C', 'G', 'U', 'C', 'U', 'C', 'C', 'G', 'U', 'U', 'U', 'G', 'A', 'C', 'G', 'A', 'G', 'U', 'A', 'A', 'G', 'U', 'C', 'C', 'U', 'A', 'A', 'G', 'U', 'C', 'A', 'A', 'C', 'A', 'U', 'G', 'C', 'A', 'C', 'A', 'G', 'C', 'G', 'C', 'U', 'G', 'G', 'G', 'U', 'U', 'C', 'G', 'C', 'C', 'C', 'A', 'G', 'C', 'G', 'C', 'A', 'A', 'A', 'A', 'G', 'A', 'A', 'A', 'C', 'A', 'A', 'C', 'A', 'A', 'C', 'A', 'A', 'C', 'A', 'A', 'C']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.conda/envs/BI/lib/python3.11/site-packages/sklearn/base.py:366, in BaseEstimator._check_n_features(self, X, reset)
#     365 try:
# --> 366     n_features = _num_features(X)
#     367 except TypeError as e:
#
# File ~/.conda/envs/BI/lib/python3.11/site-packages/sklearn/utils/validation.py:309, in _num_features(X)
#     308     message += f" where the samples are of type {type(first_sample).__qualname__}"
# --> 309     raise TypeError(message)
#     311 try:
#     312     # If X is a list of lists, for instance, we assume that all nested
#     313     # lists have the same length without checking or converting to
#     314     # a numpy array to keep this function call as cheap as possible.
#
# TypeError: Unable to find the number of features from X of type list where the samples are of type str
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 5
#       2 X_cols = ["sequence"]
#       3 Y_cols = [colname for colname in rna_data.columns if re.match("^reactivity_[0-9]{4}$", colname)]
# ----> 5 datatoXY(dataframe=rna_data[:3],
#       6          x_columns=X_cols,
#       7          y_columns=Y_cols)
#
# Cell In[72], line 5, in datatoXY(dataframe, x_columns, y_columns)
#       3 non_procc_Y = dataframe[y_columns]
#       4 #
# ----> 5 X = datatoOneHot(non_procc_X)
#       7 return X, Y
#
# Cell In[71], line 7, in datatoOneHot(X, col)
#       5     procc_sequence = [nbase for nbase in sequence]
#       6     print(procc_sequence)
# ----> 7     onehot_list.append(encoder.transform(procc_sequence))
#       9 return np.array(onehot_list)
#
# File ~/.conda/envs/BI/lib/python3.11/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/.conda/envs/BI/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:917, in OneHotEncoder.transform(self, X)
#     912 # validation of X happens in _check_X called by _transform
#     913 warn_on_unknown = self.drop is not None and self.handle_unknown in {
#     914     "ignore",
#     915     "infrequent_if_exist",
#     916 }
# --> 917 X_int, X_mask = self._transform(
#     918     X,
#     919     handle_unknown=self.handle_unknown,
#     920     force_all_finite="allow-nan",
#     921     warn_on_unknown=warn_on_unknown,
#     922 )
#     923 self._map_infrequent_categories(X_int, X_mask)
#     925 n_samples, n_features = X_int.shape
#
# File ~/.conda/envs/BI/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:155, in _BaseEncoder._transform(self, X, handle_unknown, force_all_finite, warn_on_unknown)
#     151 def _transform(
#     152     self, X, handle_unknown="error", force_all_finite=True, warn_on_unknown=False
#     153 ):
#     154     self._check_feature_names(X, reset=False)
# --> 155     self._check_n_features(X, reset=False)
#     156     X_list, n_samples, n_features = self._check_X(
#     157         X, force_all_finite=force_all_finite
#     158     )
#     160     X_int = np.zeros((n_samples, n_features), dtype=int)
#
# File ~/.conda/envs/BI/lib/python3.11/site-packages/sklearn/base.py:369, in BaseEstimator._check_n_features(self, X, reset)
#     367 except TypeError as e:
#     368     if not reset and hasattr(self, "n_features_in_"):
# --> 369         raise ValueError(
#     370             "X does not contain any features, but "
#     371             f"{self.__class__.__name__} is expecting "
#     372             f"{self.n_features_in_} features"
#     373         ) from e
#     374     # If the number of features is not defined and reset=True,
#     375     # then we skip this check
#     376     return
#
# ValueError: X does not contain any features, but OneHotEncoder is expecting 1 features
